# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**
# I left the EncoderCNN during the default implementation with ResNet50. For the DecoderCNN I used the architecture as described in the paper [Show and Tell: A Neural Image Caption Generator](https://arxiv.org/pdf/1411.4555.pdf). This paper suggests a dimension of 512 for embedding and LSTM memory. I set the batch_size to 32, which is a good average for training. I left the num_epochs at the default value of 4 and the vocab_threshold to 5.
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:**
# I left `transform_train` on the default implementation:
# - `resizing` - The images in the dataset have different sizes, so they are scaled to a uniform size
# - `crop` - The input for ResNet50 requires a 224x224 image as input. Some image information will be lost if you reduce the image size from 256x256 to 224x224. Maybe this step can be removed to capture everything on the image.
# - `random horizontal flip` - To avoid overfitting and to get more variance in the images (augmentation) the image is flipped in 50% of cases.
# - `to tensor` - Converts the image into a tensor as input for the model
# - `normalize` - Normalization of the values between 0-1 as in the pretrained model
#
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**
# In the encoder all layers are fixed except the last/output layer. This is a pretrained model (ResNet50), therefore only this layer must be trained in the encoder. The decoder is completely untrained, here all weights must be trained.
#
#
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**
# I decided to use the Adam optimizer with the default learning rate of 0.001. As described in the paper [Show, Attend and Tell: Neural Image Caption Generation with Visual Attention](https://arxiv.org/pdf/1502.03044.pdf) the Adam performed best in the COCO dataset.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32          # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True     # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 4             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.001)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=0.89s)
# creating index...
#   0%|          | 798/414113 [00:00<01:50, 3754.48it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:34<00:00, 4397.70it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/12942], Loss: 3.8277, Perplexity: 45.9585
# Epoch [1/3], Step [200/12942], Loss: 3.5514, Perplexity: 34.8626
# Epoch [1/3], Step [300/12942], Loss: 3.1137, Perplexity: 22.5043
# Epoch [1/3], Step [400/12942], Loss: 3.4705, Perplexity: 32.1530
# Epoch [1/3], Step [500/12942], Loss: 3.1414, Perplexity: 23.1360
# Epoch [1/3], Step [600/12942], Loss: 3.2264, Perplexity: 25.1888
# Epoch [1/3], Step [700/12942], Loss: 3.5362, Perplexity: 34.3346
# Epoch [1/3], Step [800/12942], Loss: 3.0619, Perplexity: 21.3686
# Epoch [1/3], Step [900/12942], Loss: 2.9645, Perplexity: 19.3847
# Epoch [1/3], Step [1000/12942], Loss: 2.9682, Perplexity: 19.4578
# Epoch [1/3], Step [1100/12942], Loss: 3.1094, Perplexity: 22.4069
# Epoch [1/3], Step [1200/12942], Loss: 2.8207, Perplexity: 16.7880
# Epoch [1/3], Step [1300/12942], Loss: 2.8046, Perplexity: 16.5207
# Epoch [1/3], Step [1400/12942], Loss: 2.7574, Perplexity: 15.7592
# Epoch [1/3], Step [1500/12942], Loss: 2.8720, Perplexity: 17.6727
# Epoch [1/3], Step [1600/12942], Loss: 2.7698, Perplexity: 15.9552
# Epoch [1/3], Step [1700/12942], Loss: 2.8041, Perplexity: 16.5121
# Epoch [1/3], Step [1800/12942], Loss: 2.9669, Perplexity: 19.4320
# Epoch [1/3], Step [1900/12942], Loss: 2.6480, Perplexity: 14.1257
# Epoch [1/3], Step [2000/12942], Loss: 2.7282, Perplexity: 15.3053
# Epoch [1/3], Step [2100/12942], Loss: 2.7542, Perplexity: 15.7091
# Epoch [1/3], Step [2200/12942], Loss: 2.8737, Perplexity: 17.7017
# Epoch [1/3], Step [2300/12942], Loss: 2.6964, Perplexity: 14.8266
# Epoch [1/3], Step [2400/12942], Loss: 2.3959, Perplexity: 10.9783
# Epoch [1/3], Step [2500/12942], Loss: 2.7199, Perplexity: 15.1786
# Epoch [1/3], Step [2600/12942], Loss: 2.8170, Perplexity: 16.7263
# Epoch [1/3], Step [2700/12942], Loss: 2.5699, Perplexity: 13.0645
# Epoch [1/3], Step [2800/12942], Loss: 2.7454, Perplexity: 15.57103
# Epoch [1/3], Step [2900/12942], Loss: 2.5371, Perplexity: 12.6433
# Epoch [1/3], Step [3000/12942], Loss: 3.1578, Perplexity: 23.5178
# Epoch [1/3], Step [3100/12942], Loss: 2.6917, Perplexity: 14.7562
# Epoch [1/3], Step [3200/12942], Loss: 2.3268, Perplexity: 10.2453
# Epoch [1/3], Step [3300/12942], Loss: 2.8103, Perplexity: 16.6143
# Epoch [1/3], Step [3400/12942], Loss: 2.7408, Perplexity: 15.5000
# Epoch [1/3], Step [3500/12942], Loss: 2.9152, Perplexity: 18.4518
# Epoch [1/3], Step [3600/12942], Loss: 2.2738, Perplexity: 9.71647
# Epoch [1/3], Step [3700/12942], Loss: 2.2428, Perplexity: 9.41998
# Epoch [1/3], Step [3800/12942], Loss: 2.2983, Perplexity: 9.95725
# Epoch [1/3], Step [3900/12942], Loss: 2.8225, Perplexity: 16.8183
# Epoch [1/3], Step [4000/12942], Loss: 2.1713, Perplexity: 8.76947
# Epoch [1/3], Step [4100/12942], Loss: 2.2183, Perplexity: 9.19144
# Epoch [1/3], Step [4200/12942], Loss: 2.4402, Perplexity: 11.4755
# Epoch [1/3], Step [4300/12942], Loss: 2.4000, Perplexity: 11.0234
# Epoch [1/3], Step [4400/12942], Loss: 2.5022, Perplexity: 12.2090
# Epoch [1/3], Step [4500/12942], Loss: 2.3116, Perplexity: 10.0904
# Epoch [1/3], Step [4600/12942], Loss: 2.2522, Perplexity: 9.50893
# Epoch [1/3], Step [4700/12942], Loss: 2.1996, Perplexity: 9.02162
# Epoch [1/3], Step [4800/12942], Loss: 2.4749, Perplexity: 11.88018
# Epoch [1/3], Step [4900/12942], Loss: 1.8521, Perplexity: 6.37313
# Epoch [1/3], Step [5000/12942], Loss: 2.2135, Perplexity: 9.14802
# Epoch [1/3], Step [5100/12942], Loss: 2.2568, Perplexity: 9.55295
# Epoch [1/3], Step [5200/12942], Loss: 2.1800, Perplexity: 8.84673
# Epoch [1/3], Step [5300/12942], Loss: 2.3678, Perplexity: 10.6739
# Epoch [1/3], Step [5400/12942], Loss: 2.3536, Perplexity: 10.5231
# Epoch [1/3], Step [5500/12942], Loss: 2.3291, Perplexity: 10.2689
# Epoch [1/3], Step [5600/12942], Loss: 2.2163, Perplexity: 9.17379
# Epoch [1/3], Step [5700/12942], Loss: 2.0866, Perplexity: 8.05748
# Epoch [1/3], Step [5800/12942], Loss: 1.9696, Perplexity: 7.16778
# Epoch [1/3], Step [5900/12942], Loss: 3.3126, Perplexity: 27.4563
# Epoch [1/3], Step [6000/12942], Loss: 2.5498, Perplexity: 12.8041
# Epoch [1/3], Step [6100/12942], Loss: 2.4955, Perplexity: 12.1276
# Epoch [1/3], Step [6200/12942], Loss: 2.2372, Perplexity: 9.36691
# Epoch [1/3], Step [6300/12942], Loss: 2.4092, Perplexity: 11.1253
# Epoch [1/3], Step [6400/12942], Loss: 2.8922, Perplexity: 18.0331
# Epoch [1/3], Step [6500/12942], Loss: 2.2382, Perplexity: 9.37618
# Epoch [1/3], Step [6600/12942], Loss: 2.0687, Perplexity: 7.91480
# Epoch [1/3], Step [6700/12942], Loss: 2.2326, Perplexity: 9.32403
# Epoch [1/3], Step [6800/12942], Loss: 2.3885, Perplexity: 10.8971
# Epoch [1/3], Step [6900/12942], Loss: 2.3624, Perplexity: 10.6163
# Epoch [1/3], Step [7000/12942], Loss: 2.6961, Perplexity: 14.8217
# Epoch [1/3], Step [7100/12942], Loss: 2.3039, Perplexity: 10.0133
# Epoch [1/3], Step [7200/12942], Loss: 2.2403, Perplexity: 9.39665
# Epoch [1/3], Step [7300/12942], Loss: 2.9508, Perplexity: 19.1204
# Epoch [1/3], Step [7400/12942], Loss: 1.8733, Perplexity: 6.50981
# Epoch [1/3], Step [7500/12942], Loss: 2.3015, Perplexity: 9.98872
# Epoch [1/3], Step [7600/12942], Loss: 3.2183, Perplexity: 24.9856
# Epoch [1/3], Step [7700/12942], Loss: 2.3296, Perplexity: 10.2742
# Epoch [1/3], Step [7800/12942], Loss: 2.3837, Perplexity: 10.8454
# Epoch [1/3], Step [7900/12942], Loss: 2.0442, Perplexity: 7.72315
# Epoch [1/3], Step [8000/12942], Loss: 2.3296, Perplexity: 10.2743
# Epoch [1/3], Step [8100/12942], Loss: 2.2692, Perplexity: 9.67148
# Epoch [1/3], Step [8200/12942], Loss: 2.2280, Perplexity: 9.28087
# Epoch [1/3], Step [8300/12942], Loss: 2.2767, Perplexity: 9.74441
# Epoch [1/3], Step [8400/12942], Loss: 2.1215, Perplexity: 8.34330
# Epoch [1/3], Step [8500/12942], Loss: 2.3254, Perplexity: 10.2308
# Epoch [1/3], Step [8600/12942], Loss: 2.6083, Perplexity: 13.5760
# Epoch [1/3], Step [8700/12942], Loss: 2.5987, Perplexity: 13.4461
# Epoch [1/3], Step [8800/12942], Loss: 2.1630, Perplexity: 8.69733
# Epoch [1/3], Step [8900/12942], Loss: 2.1012, Perplexity: 8.17577
# Epoch [1/3], Step [9000/12942], Loss: 2.1499, Perplexity: 8.58427
# Epoch [1/3], Step [9100/12942], Loss: 2.1818, Perplexity: 8.86267
# Epoch [1/3], Step [9200/12942], Loss: 2.0917, Perplexity: 8.09887
# Epoch [1/3], Step [9300/12942], Loss: 2.5481, Perplexity: 12.7822
# Epoch [1/3], Step [9400/12942], Loss: 2.3470, Perplexity: 10.4537
# Epoch [1/3], Step [9500/12942], Loss: 2.1638, Perplexity: 8.70376
# Epoch [1/3], Step [9600/12942], Loss: 1.9766, Perplexity: 7.21841
# Epoch [1/3], Step [9700/12942], Loss: 2.3958, Perplexity: 10.9766
# Epoch [1/3], Step [9800/12942], Loss: 2.7851, Perplexity: 16.2007
# Epoch [1/3], Step [9900/12942], Loss: 2.2132, Perplexity: 9.14512
# Epoch [1/3], Step [10000/12942], Loss: 2.0613, Perplexity: 7.85624
# Epoch [1/3], Step [10100/12942], Loss: 2.2271, Perplexity: 9.27268
# Epoch [1/3], Step [10200/12942], Loss: 2.2522, Perplexity: 9.50872
# Epoch [1/3], Step [10300/12942], Loss: 2.5661, Perplexity: 13.0154
# Epoch [1/3], Step [10400/12942], Loss: 2.0325, Perplexity: 7.63349
# Epoch [1/3], Step [10500/12942], Loss: 2.2307, Perplexity: 9.30666
# Epoch [1/3], Step [10600/12942], Loss: 2.5732, Perplexity: 13.1075
# Epoch [1/3], Step [10700/12942], Loss: 2.9442, Perplexity: 18.9948
# Epoch [1/3], Step [10800/12942], Loss: 3.0166, Perplexity: 20.4217
# Epoch [1/3], Step [10900/12942], Loss: 2.2446, Perplexity: 9.43639
# Epoch [1/3], Step [11000/12942], Loss: 2.1538, Perplexity: 8.61792
# Epoch [1/3], Step [11100/12942], Loss: 2.0411, Perplexity: 7.69918
# Epoch [1/3], Step [11200/12942], Loss: 2.2681, Perplexity: 9.66118
# Epoch [1/3], Step [11300/12942], Loss: 2.3036, Perplexity: 10.0102
# Epoch [1/3], Step [11400/12942], Loss: 2.9535, Perplexity: 19.1737
# Epoch [1/3], Step [11500/12942], Loss: 1.8755, Perplexity: 6.52387
# Epoch [1/3], Step [11600/12942], Loss: 1.8645, Perplexity: 6.45258
# Epoch [1/3], Step [11700/12942], Loss: 2.3361, Perplexity: 10.3412
# Epoch [1/3], Step [11800/12942], Loss: 2.3210, Perplexity: 10.1855
# Epoch [1/3], Step [11900/12942], Loss: 2.1958, Perplexity: 8.98681
# Epoch [1/3], Step [12000/12942], Loss: 1.9793, Perplexity: 7.23781
# Epoch [1/3], Step [12100/12942], Loss: 2.3156, Perplexity: 10.1308
# Epoch [1/3], Step [12200/12942], Loss: 2.4550, Perplexity: 11.6467
# Epoch [1/3], Step [12300/12942], Loss: 2.3373, Perplexity: 10.3534
# Epoch [1/3], Step [12400/12942], Loss: 2.2547, Perplexity: 9.53243
# Epoch [1/3], Step [12500/12942], Loss: 2.2414, Perplexity: 9.406651
# Epoch [1/3], Step [12600/12942], Loss: 1.8478, Perplexity: 6.34596
# Epoch [1/3], Step [12700/12942], Loss: 2.5465, Perplexity: 12.7626
# Epoch [1/3], Step [12800/12942], Loss: 2.2752, Perplexity: 9.72970
# Epoch [1/3], Step [12900/12942], Loss: 2.1989, Perplexity: 9.01540
# Epoch [2/3], Step [100/12942], Loss: 2.2621, Perplexity: 9.6029619
# Epoch [2/3], Step [200/12942], Loss: 2.1505, Perplexity: 8.58889
# Epoch [2/3], Step [300/12942], Loss: 1.9397, Perplexity: 6.95637
# Epoch [2/3], Step [400/12942], Loss: 2.3024, Perplexity: 9.99823
# Epoch [2/3], Step [500/12942], Loss: 2.2167, Perplexity: 9.17701
# Epoch [2/3], Step [600/12942], Loss: 2.2683, Perplexity: 9.66299
# Epoch [2/3], Step [700/12942], Loss: 2.6019, Perplexity: 13.4890
# Epoch [2/3], Step [800/12942], Loss: 1.8210, Perplexity: 6.17829
# Epoch [2/3], Step [900/12942], Loss: 2.3346, Perplexity: 10.3257
# Epoch [2/3], Step [1000/12942], Loss: 2.1444, Perplexity: 8.5366
# Epoch [2/3], Step [1100/12942], Loss: 2.0288, Perplexity: 7.605293
# Epoch [2/3], Step [1200/12942], Loss: 2.3690, Perplexity: 10.6869
# Epoch [2/3], Step [1300/12942], Loss: 2.0387, Perplexity: 7.68102
# Epoch [2/3], Step [1400/12942], Loss: 2.5116, Perplexity: 12.3247
# Epoch [2/3], Step [1500/12942], Loss: 2.7984, Perplexity: 16.4186
# Epoch [2/3], Step [1600/12942], Loss: 2.1621, Perplexity: 8.68946
# Epoch [2/3], Step [1700/12942], Loss: 1.9937, Perplexity: 7.34280
# Epoch [2/3], Step [1800/12942], Loss: 2.3096, Perplexity: 10.0708
# Epoch [2/3], Step [1900/12942], Loss: 2.0790, Perplexity: 7.99669
# Epoch [2/3], Step [2000/12942], Loss: 2.3402, Perplexity: 10.3834
# Epoch [2/3], Step [2100/12942], Loss: 2.7660, Perplexity: 15.8955
# Epoch [2/3], Step [2200/12942], Loss: 2.0115, Perplexity: 7.47465
# Epoch [2/3], Step [2300/12942], Loss: 1.8492, Perplexity: 6.35453
# Epoch [2/3], Step [2400/12942], Loss: 1.8814, Perplexity: 6.56307
# Epoch [2/3], Step [2500/12942], Loss: 2.1791, Perplexity: 8.83838
# Epoch [2/3], Step [2600/12942], Loss: 1.9919, Perplexity: 7.32973
# Epoch [2/3], Step [2700/12942], Loss: 1.9886, Perplexity: 7.30510
# Epoch [2/3], Step [2800/12942], Loss: 2.0077, Perplexity: 7.44631
# Epoch [2/3], Step [2900/12942], Loss: 2.0788, Perplexity: 7.99511
# Epoch [2/3], Step [3000/12942], Loss: 1.9683, Perplexity: 7.15865
# Epoch [2/3], Step [3100/12942], Loss: 2.1278, Perplexity: 8.39652
# Epoch [2/3], Step [3200/12942], Loss: 2.2238, Perplexity: 9.24276
# Epoch [2/3], Step [3300/12942], Loss: 2.0569, Perplexity: 7.82175
# Epoch [2/3], Step [3400/12942], Loss: 2.1248, Perplexity: 8.37092
# Epoch [2/3], Step [3500/12942], Loss: 2.8576, Perplexity: 17.4201
# Epoch [2/3], Step [3600/12942], Loss: 1.9129, Perplexity: 6.77286
# Epoch [2/3], Step [3700/12942], Loss: 2.1500, Perplexity: 8.58453
# Epoch [2/3], Step [3800/12942], Loss: 1.7606, Perplexity: 5.81617
# Epoch [2/3], Step [3900/12942], Loss: 2.1919, Perplexity: 8.95197
# Epoch [2/3], Step [4000/12942], Loss: 2.2104, Perplexity: 9.11934
# Epoch [2/3], Step [4100/12942], Loss: 1.9143, Perplexity: 6.78192
# Epoch [2/3], Step [4200/12942], Loss: 2.0435, Perplexity: 7.71749
# Epoch [2/3], Step [4300/12942], Loss: 2.0476, Perplexity: 7.74920
# Epoch [2/3], Step [4400/12942], Loss: 2.8058, Perplexity: 16.5409
# Epoch [2/3], Step [4500/12942], Loss: 2.3092, Perplexity: 10.0667
# Epoch [2/3], Step [4600/12942], Loss: 1.8904, Perplexity: 6.62223
# Epoch [2/3], Step [4700/12942], Loss: 2.0204, Perplexity: 7.54142
# Epoch [2/3], Step [4800/12942], Loss: 2.0524, Perplexity: 7.78647
# Epoch [2/3], Step [4900/12942], Loss: 2.2441, Perplexity: 9.43239
# Epoch [2/3], Step [5000/12942], Loss: 2.2240, Perplexity: 9.24417
# Epoch [2/3], Step [5100/12942], Loss: 2.2131, Perplexity: 9.14411
# Epoch [2/3], Step [5200/12942], Loss: 2.0482, Perplexity: 7.75421
# Epoch [2/3], Step [5300/12942], Loss: 2.0981, Perplexity: 8.15052
# Epoch [2/3], Step [5400/12942], Loss: 2.5026, Perplexity: 12.2139
# Epoch [2/3], Step [5500/12942], Loss: 1.9620, Perplexity: 7.11350
# Epoch [2/3], Step [5600/12942], Loss: 2.1933, Perplexity: 8.96481
# Epoch [2/3], Step [5700/12942], Loss: 2.0582, Perplexity: 7.83207
# Epoch [2/3], Step [5800/12942], Loss: 2.4270, Perplexity: 11.3244
# Epoch [2/3], Step [5900/12942], Loss: 1.9427, Perplexity: 6.97732
# Epoch [2/3], Step [6000/12942], Loss: 2.1422, Perplexity: 8.51817
# Epoch [2/3], Step [6100/12942], Loss: 2.1323, Perplexity: 8.43443
# Epoch [2/3], Step [6200/12942], Loss: 1.9593, Perplexity: 7.09406
# Epoch [2/3], Step [6300/12942], Loss: 2.0504, Perplexity: 7.77099
# Epoch [2/3], Step [6400/12942], Loss: 2.1627, Perplexity: 8.69444
# Epoch [2/3], Step [6500/12942], Loss: 2.0582, Perplexity: 7.83218
# Epoch [2/3], Step [6600/12942], Loss: 2.1479, Perplexity: 8.56681
# Epoch [2/3], Step [6700/12942], Loss: 2.1271, Perplexity: 8.39048
# Epoch [2/3], Step [6800/12942], Loss: 2.3272, Perplexity: 10.2495
# Epoch [2/3], Step [6900/12942], Loss: 2.4297, Perplexity: 11.3553
# Epoch [2/3], Step [7000/12942], Loss: 2.1066, Perplexity: 8.22027
# Epoch [2/3], Step [7100/12942], Loss: 2.2617, Perplexity: 9.59958
# Epoch [2/3], Step [7200/12942], Loss: 2.1347, Perplexity: 8.45468
# Epoch [2/3], Step [7300/12942], Loss: 2.4648, Perplexity: 11.7610
# Epoch [2/3], Step [7400/12942], Loss: 2.1872, Perplexity: 8.91022
# Epoch [2/3], Step [7500/12942], Loss: 1.9500, Perplexity: 7.02861
# Epoch [2/3], Step [7600/12942], Loss: 2.1812, Perplexity: 8.85714
# Epoch [2/3], Step [7700/12942], Loss: 2.2577, Perplexity: 9.56158
# Epoch [2/3], Step [7800/12942], Loss: 2.2958, Perplexity: 9.93251
# Epoch [2/3], Step [7900/12942], Loss: 2.1844, Perplexity: 8.88567
# Epoch [2/3], Step [8000/12942], Loss: 2.0288, Perplexity: 7.60519
# Epoch [2/3], Step [8100/12942], Loss: 2.0615, Perplexity: 7.85790
# Epoch [2/3], Step [8200/12942], Loss: 2.0412, Perplexity: 7.69959
# Epoch [2/3], Step [8300/12942], Loss: 2.4239, Perplexity: 11.2902
# Epoch [2/3], Step [8400/12942], Loss: 2.3571, Perplexity: 10.5605
# Epoch [2/3], Step [8500/12942], Loss: 1.8377, Perplexity: 6.28209
# Epoch [2/3], Step [8600/12942], Loss: 1.9857, Perplexity: 7.28399
# Epoch [2/3], Step [8700/12942], Loss: 2.4410, Perplexity: 11.4851
# Epoch [2/3], Step [8800/12942], Loss: 2.0136, Perplexity: 7.49060
# Epoch [2/3], Step [8900/12942], Loss: 1.9305, Perplexity: 6.89315
# Epoch [2/3], Step [9000/12942], Loss: 1.9607, Perplexity: 7.10436
# Epoch [2/3], Step [9100/12942], Loss: 2.1750, Perplexity: 8.80197
# Epoch [2/3], Step [9200/12942], Loss: 2.0605, Perplexity: 7.84968
# Epoch [2/3], Step [9300/12942], Loss: 2.0320, Perplexity: 7.62951
# Epoch [2/3], Step [9400/12942], Loss: 2.0181, Perplexity: 7.52430
# Epoch [2/3], Step [9500/12942], Loss: 2.4340, Perplexity: 11.4045
# Epoch [2/3], Step [9600/12942], Loss: 1.8741, Perplexity: 6.51493
# Epoch [2/3], Step [9700/12942], Loss: 3.0387, Perplexity: 20.8786
# Epoch [2/3], Step [9800/12942], Loss: 2.2928, Perplexity: 9.90319
# Epoch [2/3], Step [9900/12942], Loss: 1.9758, Perplexity: 7.21274
# Epoch [2/3], Step [10000/12942], Loss: 2.3339, Perplexity: 10.3180
# Epoch [2/3], Step [10100/12942], Loss: 2.2145, Perplexity: 9.15667
# Epoch [2/3], Step [10200/12942], Loss: 2.0723, Perplexity: 7.94312
# Epoch [2/3], Step [10300/12942], Loss: 2.2816, Perplexity: 9.79212
# Epoch [2/3], Step [10400/12942], Loss: 1.8757, Perplexity: 6.52521
# Epoch [2/3], Step [10500/12942], Loss: 2.1421, Perplexity: 8.51703
# Epoch [2/3], Step [10600/12942], Loss: 2.2132, Perplexity: 9.14478
# Epoch [2/3], Step [10700/12942], Loss: 2.1327, Perplexity: 8.43734
# Epoch [2/3], Step [10800/12942], Loss: 2.1000, Perplexity: 8.16593
# Epoch [2/3], Step [10900/12942], Loss: 2.2774, Perplexity: 9.75145
# Epoch [2/3], Step [11000/12942], Loss: 2.0362, Perplexity: 7.66113
# Epoch [2/3], Step [11100/12942], Loss: 1.9511, Perplexity: 7.03667
# Epoch [2/3], Step [11200/12942], Loss: 2.3856, Perplexity: 10.8653
# Epoch [2/3], Step [11300/12942], Loss: 1.8382, Perplexity: 6.28492
# Epoch [2/3], Step [11400/12942], Loss: 2.0217, Perplexity: 7.55114
# Epoch [2/3], Step [11500/12942], Loss: 2.0163, Perplexity: 7.51072
# Epoch [2/3], Step [11600/12942], Loss: 1.9546, Perplexity: 7.06094
# Epoch [2/3], Step [11700/12942], Loss: 2.2479, Perplexity: 9.46754
# Epoch [2/3], Step [11800/12942], Loss: 2.0939, Perplexity: 8.11645
# Epoch [2/3], Step [11900/12942], Loss: 1.9555, Perplexity: 7.06738
# Epoch [2/3], Step [12000/12942], Loss: 2.0821, Perplexity: 8.02152
# Epoch [2/3], Step [12100/12942], Loss: 2.1419, Perplexity: 8.51541
# Epoch [2/3], Step [12200/12942], Loss: 2.0167, Perplexity: 7.51353
# Epoch [2/3], Step [12300/12942], Loss: 2.4133, Perplexity: 11.1702
# Epoch [2/3], Step [12400/12942], Loss: 1.9898, Perplexity: 7.31435
# Epoch [2/3], Step [12500/12942], Loss: 1.9595, Perplexity: 7.09560
# Epoch [2/3], Step [12600/12942], Loss: 2.0668, Perplexity: 7.89957
# Epoch [2/3], Step [12700/12942], Loss: 1.8171, Perplexity: 6.15428
# Epoch [2/3], Step [12800/12942], Loss: 2.2362, Perplexity: 9.35741
# Epoch [2/3], Step [12900/12942], Loss: 2.0749, Perplexity: 7.96342
# Epoch [3/3], Step [100/12942], Loss: 2.1013, Perplexity: 8.1767259
# Epoch [3/3], Step [200/12942], Loss: 1.9552, Perplexity: 7.06527
# Epoch [3/3], Step [300/12942], Loss: 2.0015, Perplexity: 7.40049
# Epoch [3/3], Step [400/12942], Loss: 2.1474, Perplexity: 8.56230
# Epoch [3/3], Step [500/12942], Loss: 2.1858, Perplexity: 8.89779
# Epoch [3/3], Step [600/12942], Loss: 2.6729, Perplexity: 14.4818
# Epoch [3/3], Step [700/12942], Loss: 2.3447, Perplexity: 10.4296
# Epoch [3/3], Step [800/12942], Loss: 2.0861, Perplexity: 8.053661
# Epoch [3/3], Step [900/12942], Loss: 2.0200, Perplexity: 7.53846
# Epoch [3/3], Step [1000/12942], Loss: 2.1214, Perplexity: 8.3427
# Epoch [3/3], Step [1100/12942], Loss: 2.1565, Perplexity: 8.64047
# Epoch [3/3], Step [1200/12942], Loss: 2.0636, Perplexity: 7.87467
# Epoch [3/3], Step [1300/12942], Loss: 2.0813, Perplexity: 8.01529
# Epoch [3/3], Step [1400/12942], Loss: 2.0650, Perplexity: 7.88554
# Epoch [3/3], Step [1500/12942], Loss: 1.8457, Perplexity: 6.33254
# Epoch [3/3], Step [1600/12942], Loss: 1.9685, Perplexity: 7.16014
# Epoch [3/3], Step [1700/12942], Loss: 2.0080, Perplexity: 7.44884
# Epoch [3/3], Step [1800/12942], Loss: 2.1645, Perplexity: 8.71052
# Epoch [3/3], Step [1900/12942], Loss: 3.0476, Perplexity: 21.0639
# Epoch [3/3], Step [2000/12942], Loss: 2.0797, Perplexity: 8.00247
# Epoch [3/3], Step [2100/12942], Loss: 2.4456, Perplexity: 11.5372
# Epoch [3/3], Step [2200/12942], Loss: 1.8999, Perplexity: 6.68495
# Epoch [3/3], Step [2300/12942], Loss: 1.9342, Perplexity: 6.91845
# Epoch [3/3], Step [2400/12942], Loss: 2.3035, Perplexity: 10.0091
# Epoch [3/3], Step [2500/12942], Loss: 1.9506, Perplexity: 7.03296
# Epoch [3/3], Step [2600/12942], Loss: 2.0536, Perplexity: 7.79607
# Epoch [3/3], Step [2700/12942], Loss: 2.1094, Perplexity: 8.24341
# Epoch [3/3], Step [2800/12942], Loss: 2.0354, Perplexity: 7.65526
# Epoch [3/3], Step [2900/12942], Loss: 1.9365, Perplexity: 6.93418
# Epoch [3/3], Step [3000/12942], Loss: 2.1663, Perplexity: 8.72635
# Epoch [3/3], Step [3100/12942], Loss: 2.3718, Perplexity: 10.7162
# Epoch [3/3], Step [3200/12942], Loss: 2.0844, Perplexity: 8.03960
# Epoch [3/3], Step [3300/12942], Loss: 1.9183, Perplexity: 6.80943
# Epoch [3/3], Step [3400/12942], Loss: 2.5550, Perplexity: 12.8718
# Epoch [3/3], Step [3500/12942], Loss: 3.0650, Perplexity: 21.4335
# Epoch [3/3], Step [3600/12942], Loss: 1.9560, Perplexity: 7.07101
# Epoch [3/3], Step [3700/12942], Loss: 3.0503, Perplexity: 21.1210
# Epoch [3/3], Step [3800/12942], Loss: 1.8755, Perplexity: 6.52429
# Epoch [3/3], Step [3900/12942], Loss: 2.1140, Perplexity: 8.28115
# Epoch [3/3], Step [4000/12942], Loss: 1.8704, Perplexity: 6.49071
# Epoch [3/3], Step [4100/12942], Loss: 2.1242, Perplexity: 8.36643
# Epoch [3/3], Step [4200/12942], Loss: 2.0026, Perplexity: 7.40798
# Epoch [3/3], Step [4300/12942], Loss: 2.0143, Perplexity: 7.49554
# Epoch [3/3], Step [4400/12942], Loss: 2.0395, Perplexity: 7.68677
# Epoch [3/3], Step [4500/12942], Loss: 2.1764, Perplexity: 8.81423
# Epoch [3/3], Step [4600/12942], Loss: 2.0854, Perplexity: 8.04829
# Epoch [3/3], Step [4700/12942], Loss: 2.1571, Perplexity: 8.64578
# Epoch [3/3], Step [4800/12942], Loss: 2.2316, Perplexity: 9.31502
# Epoch [3/3], Step [4900/12942], Loss: 1.8973, Perplexity: 6.66804
# Epoch [3/3], Step [5000/12942], Loss: 2.0465, Perplexity: 7.74056
# Epoch [3/3], Step [5100/12942], Loss: 2.0250, Perplexity: 7.57608
# Epoch [3/3], Step [5200/12942], Loss: 2.0212, Perplexity: 7.54762
# Epoch [3/3], Step [5300/12942], Loss: 2.1786, Perplexity: 8.83370
# Epoch [3/3], Step [5400/12942], Loss: 1.8094, Perplexity: 6.10707
# Epoch [3/3], Step [5500/12942], Loss: 2.0552, Perplexity: 7.80800
# Epoch [3/3], Step [5600/12942], Loss: 1.7252, Perplexity: 5.61366
# Epoch [3/3], Step [5700/12942], Loss: 2.0119, Perplexity: 7.47737
# Epoch [3/3], Step [5800/12942], Loss: 1.9142, Perplexity: 6.78181
# Epoch [3/3], Step [5900/12942], Loss: 1.8790, Perplexity: 6.54697
# Epoch [3/3], Step [6000/12942], Loss: 1.9264, Perplexity: 6.86484
# Epoch [3/3], Step [6100/12942], Loss: 2.3654, Perplexity: 10.6485
# Epoch [3/3], Step [6200/12942], Loss: 2.0476, Perplexity: 7.74933
# Epoch [3/3], Step [6300/12942], Loss: 2.0871, Perplexity: 8.06165
# Epoch [3/3], Step [6400/12942], Loss: 1.9650, Perplexity: 7.13529
# Epoch [3/3], Step [6500/12942], Loss: 1.8832, Perplexity: 6.57461
# Epoch [3/3], Step [6600/12942], Loss: 1.9791, Perplexity: 7.23634
# Epoch [3/3], Step [6700/12942], Loss: 2.2305, Perplexity: 9.30455
# Epoch [3/3], Step [6800/12942], Loss: 1.8656, Perplexity: 6.45972
# Epoch [3/3], Step [6900/12942], Loss: 1.9777, Perplexity: 7.22587
# Epoch [3/3], Step [7000/12942], Loss: 2.1940, Perplexity: 8.97147
# Epoch [3/3], Step [7100/12942], Loss: 2.0411, Perplexity: 7.69935
# Epoch [3/3], Step [7200/12942], Loss: 2.0315, Perplexity: 7.62526
# Epoch [3/3], Step [7300/12942], Loss: 1.7970, Perplexity: 6.03155
# Epoch [3/3], Step [7400/12942], Loss: 1.9289, Perplexity: 6.88170
# Epoch [3/3], Step [7500/12942], Loss: 2.1442, Perplexity: 8.53552
# Epoch [3/3], Step [7600/12942], Loss: 1.9911, Perplexity: 7.32388
# Epoch [3/3], Step [7700/12942], Loss: 2.2973, Perplexity: 9.94746
# Epoch [3/3], Step [7800/12942], Loss: 2.2086, Perplexity: 9.10305
# Epoch [3/3], Step [7900/12942], Loss: 1.8986, Perplexity: 6.67652
# Epoch [3/3], Step [8000/12942], Loss: 1.9361, Perplexity: 6.93143
# Epoch [3/3], Step [8100/12942], Loss: 2.0143, Perplexity: 7.49588
# Epoch [3/3], Step [8200/12942], Loss: 2.0764, Perplexity: 7.97582
# Epoch [3/3], Step [8300/12942], Loss: 2.3487, Perplexity: 10.4717
# Epoch [3/3], Step [8400/12942], Loss: 1.7081, Perplexity: 5.51845
# Epoch [3/3], Step [8500/12942], Loss: 2.0965, Perplexity: 8.13734
# Epoch [3/3], Step [8600/12942], Loss: 1.8886, Perplexity: 6.61023
# Epoch [3/3], Step [8700/12942], Loss: 2.0876, Perplexity: 8.06534
# Epoch [3/3], Step [8800/12942], Loss: 2.1692, Perplexity: 8.75119
# Epoch [3/3], Step [8900/12942], Loss: 2.4065, Perplexity: 11.0951
# Epoch [3/3], Step [9000/12942], Loss: 2.0117, Perplexity: 7.47597
# Epoch [3/3], Step [9100/12942], Loss: 2.1357, Perplexity: 8.46282
# Epoch [3/3], Step [9200/12942], Loss: 2.1417, Perplexity: 8.51439
# Epoch [3/3], Step [9300/12942], Loss: 2.0615, Perplexity: 7.85751
# Epoch [3/3], Step [9400/12942], Loss: 1.8593, Perplexity: 6.41950
# Epoch [3/3], Step [9500/12942], Loss: 1.9814, Perplexity: 7.25285
# Epoch [3/3], Step [9600/12942], Loss: 1.8957, Perplexity: 6.65718
# Epoch [3/3], Step [9700/12942], Loss: 2.3410, Perplexity: 10.3914
# Epoch [3/3], Step [9800/12942], Loss: 2.0632, Perplexity: 7.87135
# Epoch [3/3], Step [9900/12942], Loss: 1.9121, Perplexity: 6.76707
# Epoch [3/3], Step [10000/12942], Loss: 2.2244, Perplexity: 9.2475
# Epoch [3/3], Step [10100/12942], Loss: 1.8532, Perplexity: 6.38041
# Epoch [3/3], Step [10200/12942], Loss: 1.9437, Perplexity: 6.98443
# Epoch [3/3], Step [10300/12942], Loss: 2.0575, Perplexity: 7.82611
# Epoch [3/3], Step [10400/12942], Loss: 2.1623, Perplexity: 8.69094
# Epoch [3/3], Step [10500/12942], Loss: 3.2624, Perplexity: 26.1117
# Epoch [3/3], Step [10600/12942], Loss: 1.8728, Perplexity: 6.50660
# Epoch [3/3], Step [10700/12942], Loss: 1.7208, Perplexity: 5.58903
# Epoch [3/3], Step [10800/12942], Loss: 2.3406, Perplexity: 10.3874
# Epoch [3/3], Step [10900/12942], Loss: 1.6635, Perplexity: 5.27801
# Epoch [3/3], Step [11000/12942], Loss: 1.8786, Perplexity: 6.54445
# Epoch [3/3], Step [11100/12942], Loss: 1.8395, Perplexity: 6.29351
# Epoch [3/3], Step [11200/12942], Loss: 2.2311, Perplexity: 9.31018
# Epoch [3/3], Step [11300/12942], Loss: 1.8973, Perplexity: 6.66774
# Epoch [3/3], Step [11400/12942], Loss: 2.1761, Perplexity: 8.81216
# Epoch [3/3], Step [11500/12942], Loss: 1.9738, Perplexity: 7.19807
# Epoch [3/3], Step [11600/12942], Loss: 2.2102, Perplexity: 9.11751
# Epoch [3/3], Step [11700/12942], Loss: 1.9197, Perplexity: 6.81883
# Epoch [3/3], Step [11800/12942], Loss: 2.0087, Perplexity: 7.45391
# Epoch [3/3], Step [11900/12942], Loss: 2.0898, Perplexity: 8.08336
# Epoch [3/3], Step [12000/12942], Loss: 1.8209, Perplexity: 6.17776
# Epoch [3/3], Step [12100/12942], Loss: 2.2980, Perplexity: 9.95468
# Epoch [3/3], Step [12200/12942], Loss: 1.8965, Perplexity: 6.66236
# Epoch [3/3], Step [12300/12942], Loss: 1.9334, Perplexity: 6.91332
# Epoch [3/3], Step [12400/12942], Loss: 2.0257, Perplexity: 7.58131
# Epoch [3/3], Step [12500/12942], Loss: 2.0445, Perplexity: 7.72519
# Epoch [3/3], Step [12600/12942], Loss: 2.2164, Perplexity: 9.17390
# Epoch [3/3], Step [12700/12942], Loss: 1.8235, Perplexity: 6.19345
# Epoch [3/3], Step [12800/12942], Loss: 2.3442, Perplexity: 10.4247
# Epoch [3/3], Step [12900/12942], Loss: 1.8989, Perplexity: 6.67845
# Epoch [3/3], Step [12942/12942], Loss: 1.7649, Perplexity: 5.84077

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
